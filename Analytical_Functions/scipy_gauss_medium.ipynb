# %% [markdown]
# ### Medium Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import os 
from zipfile import ZipFile, ZIP_DEFLATED

# %%
path = '../saved_data/'
file = f'math_functions_{dataset_type}.nc'

# %%
ds = xr.open_dataset(path + file)

# %%
gaussians = ds["Gaussians"].values
binary = ds["BinaryArr"].values
x = ds["x"].values
peak_idx = np.where(binary == 1)

# %%
random_state = 42

# %%
from scipy.signal import find_peaks

# %%
plt.close()

# %%
plt.figure(figsize=(10,6))
for i in range(3):
    peaks, _ = find_peaks(gaussians[i], height=0)
    plt.plot(x, gaussians[i])
    plt.scatter(x[peaks], gaussians[i][peaks])
