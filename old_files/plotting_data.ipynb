# %%
import xarray as xr
file = '/nsls2/users/shasko/Repos/internship_2025/saved_data/math_functions_smalldataset.nc'
ds = xr.open_dataset(file)

# %%
import numpy as np
import matplotlib.pyplot as plt

inten = ds['Gaussians'].values

# %%
plt.figure()
for j in range(5):
    plt.plot(inten[j])
plt.show()
